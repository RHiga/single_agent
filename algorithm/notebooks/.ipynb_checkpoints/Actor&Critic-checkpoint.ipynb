# %% [markdown]
# # Actor & Critic Method

# %% [markdown]
# ## Prepare the packages

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
if "../" not in sys.path:
    sys.path.append("../")

# %%
import numpy as np
import gym
from el_agent import ELAgent
from frozen_lake_util import show_q_value

# %% [markdown]
# ## Define Actor

# %%
class Actor(ELAgent):

    def __init__(self, env):
        super().__init__(epsilon=-1)
        nrow = env.observation_space.n
        ncol = env.action_space.n
        self.actions = list(range(env.action_space.n))
        self.Q = np.random.uniform(0, 1, nrow * ncol).reshape((nrow, ncol))

    def softmax(self, x):
        return np.exp(x) / np.sum(np.exp(x), axis=0)

    def policy(self, s):
        a = np.random.choice(self.actions, 1,
                             p=self.softmax(self.Q[s]))
        return a[0]

# %% [markdown]
# ## Define Critic

# %%
class Critic():

    def __init__(self, env):
        states = env.observation_space.n
        self.V = np.zeros(states)

# %% [markdown]
# ## Define Actor & Critic Training Process

# %%
class ActorCritic():

    def __init__(self, actor_class, critic_class):
        self.actor_class = actor_class
        self.critic_class = critic_class

    def train(self, env, episode_count=1000, gamma=0.9,
              learning_rate=0.1, render=False, report_interval=50):
        actor = self.actor_class(env)
        critic = self.critic_class(env)

        actor.init_log()
        for e in range(episode_count):
            s = env.reset()
            done = False
            while not done:
                if render:
                    env.render()
                a = actor.policy(s)
                n_state, reward, done, info = env.step(a)

                gain = reward + gamma * critic.V[n_state]
                estimated = critic.V[s]
                td = gain - estimated
                actor.Q[s][a] += learning_rate * td
                critic.V[s] += learning_rate * td
                s = n_state

            else:
                actor.log(reward)

            if e != 0 and e % report_interval == 0:
                actor.show_reward_log(episode=e)

        return actor, critic

# %% [markdown]
# ## Train Agent

# %%
def train():
    trainer = ActorCritic(Actor, Critic)
    env = gym.make("FrozenLakeEasy-v0")
    actor, critic = trainer.train(env, episode_count=3000)
    show_q_value(actor.Q)
    actor.show_reward_log()

# %%
agent = train()
# Out:
# At Episode 50 average reward is 0.02 (+/-0.14).
# At Episode 100 average reward is 0.0 (+/-0.0).
# At Episode 150 average reward is 0.02 (+/-0.14).
# At Episode 200 average reward is 0.0 (+/-0.0).
# At Episode 250 average reward is 0.04 (+/-0.196).
# At Episode 300 average reward is 0.04 (+/-0.196).
# At Episode 350 average reward is 0.0 (+/-0.0).
# At Episode 400 average reward is 0.02 (+/-0.14).
# At Episode 450 average reward is 0.0 (+/-0.0).
# At Episode 500 average reward is 0.06 (+/-0.237).
# At Episode 550 average reward is 0.02 (+/-0.14).
# At Episode 600 average reward is 0.02 (+/-0.14).
# At Episode 650 average reward is 0.02 (+/-0.14).
# At Episode 700 average reward is 0.04 (+/-0.196).
# At Episode 750 average reward is 0.08 (+/-0.271).
# At Episode 800 average reward is 0.08 (+/-0.271).
# At Episode 850 average reward is 0.06 (+/-0.237).
# At Episode 900 average reward is 0.08 (+/-0.271).
# At Episode 950 average reward is 0.02 (+/-0.14).
# At Episode 1000 average reward is 0.16 (+/-0.367).
# At Episode 1050 average reward is 0.16 (+/-0.367).
# At Episode 1100 average reward is 0.34 (+/-0.474).
# At Episode 1150 average reward is 0.22 (+/-0.414).
# At Episode 1200 average reward is 0.34 (+/-0.474).
# At Episode 1250 average reward is 0.4 (+/-0.49).
# At Episode 1300 average reward is 0.62 (+/-0.485).
# At Episode 1350 average reward is 0.72 (+/-0.449).
# At Episode 1400 average reward is 0.8 (+/-0.4).
# At Episode 1450 average reward is 0.84 (+/-0.367).
# At Episode 1500 average reward is 0.88 (+/-0.325).
# At Episode 1550 average reward is 0.88 (+/-0.325).
# At Episode 1600 average reward is 0.94 (+/-0.237).
# At Episode 1650 average reward is 0.92 (+/-0.271).
# At Episode 1700 average reward is 0.9 (+/-0.3).
# At Episode 1750 average reward is 0.94 (+/-0.237).
# At Episode 1800 average reward is 1.0 (+/-0.0).
# At Episode 1850 average reward is 0.94 (+/-0.237).
# At Episode 1900 average reward is 0.98 (+/-0.14).
# At Episode 1950 average reward is 0.96 (+/-0.196).
# At Episode 2000 average reward is 0.9 (+/-0.3).
# At Episode 2050 average reward is 0.94 (+/-0.237).
# At Episode 2100 average reward is 1.0 (+/-0.0).
# At Episode 2150 average reward is 0.98 (+/-0.14).
# At Episode 2200 average reward is 0.98 (+/-0.14).
# At Episode 2250 average reward is 0.96 (+/-0.196).
# At Episode 2300 average reward is 1.0 (+/-0.0).
# At Episode 2350 average reward is 0.92 (+/-0.271).
# At Episode 2400 average reward is 1.0 (+/-0.0).
# At Episode 2450 average reward is 1.0 (+/-0.0).
# At Episode 2500 average reward is 0.98 (+/-0.14).
# At Episode 2550 average reward is 1.0 (+/-0.0).
# At Episode 2600 average reward is 1.0 (+/-0.0).
# At Episode 2650 average reward is 0.98 (+/-0.14).
# At Episode 2700 average reward is 0.96 (+/-0.196).
# At Episode 2750 average reward is 1.0 (+/-0.0).
# At Episode 2800 average reward is 1.0 (+/-0.0).
# At Episode 2850 average reward is 1.0 (+/-0.0).
# At Episode 2900 average reward is 0.98 (+/-0.14).
# At Episode 2950 average reward is 0.96 (+/-0.196).
